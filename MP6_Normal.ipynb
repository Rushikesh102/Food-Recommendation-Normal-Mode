# %% [markdown]
# # Connect to Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Load CSV File

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

path='/content/drive/My Drive/Colab Notebooks/indianFood.csv'
df=pd.read_csv(path)
df.head()
# Out:
#              name                                        ingredients  \
# 0      Balu shahi                    Maida flour, yogurt, oil, sugar
# 1          Boondi                            Gram flour, ghee, sugar
# 2  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4     Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
#
#          diet flavor_profile   course        state region
# 0  vegetarian          sweet  dessert  West Bengal   East
# 1  vegetarian          sweet  dessert    Rajasthan   West
# 2  vegetarian          sweet  dessert       Punjab  North
# 3  vegetarian          sweet  dessert    Rajasthan   West
# 4  vegetarian          sweet  dessert  West Bengal   East

# %%
data=df
data.head()
# Out:
#              name                                        ingredients  \
# 0      Balu shahi                    Maida flour, yogurt, oil, sugar
# 1          Boondi                            Gram flour, ghee, sugar
# 2  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4     Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
#
#          diet flavor_profile   course        state region
# 0  vegetarian          sweet  dessert  West Bengal   East
# 1  vegetarian          sweet  dessert    Rajasthan   West
# 2  vegetarian          sweet  dessert       Punjab  North
# 3  vegetarian          sweet  dessert    Rajasthan   West
# 4  vegetarian          sweet  dessert  West Bengal   East

# %% [markdown]
# # Create Overview

# %%
import pandas as pd
def join_columns(X):
    separator = ','
    col_name = 'Overview'
    for i, c in enumerate(X.columns):
        if i == 0:
            X_out = X[c].astype(str).copy()
        else:
            X_out += separator + X[c].astype(str)
    return X_out.to_frame(name=col_name)
d1=data.drop("name",axis=1)
data['Overview']=join_columns(d1)
data
# Out:
#                name                                        ingredients  \
# 0        Balu shahi                    Maida flour, yogurt, oil, sugar
# 1            Boondi                            Gram flour, ghee, sugar
# 2    Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3            Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4       Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# ..              ...                                                ...
# 250       Til Pitha            Glutinous rice, black sesame seeds, gur
# 251         Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 252          Shufta  Cottage cheese, dry dates, dried rose petals, ...
# 253       Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 254          Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#            diet flavor_profile   course            state      region  \
# 0    vegetarian          sweet  dessert      West Bengal        East
# 1    vegetarian          sweet  dessert        Rajasthan        West
# 2    vegetarian          sweet  dessert           Punjab       North
# 3    vegetarian          sweet  dessert        Rajasthan        West
# 4    vegetarian          sweet  dessert      West Bengal        East
# ..          ...            ...      ...              ...         ...
# 250  vegetarian          sweet  dessert            Assam  North East
# 251  vegetarian          sweet  dessert              Goa        West
# 252  vegetarian          sweet  dessert  Jammu & Kashmir       North
# 253  vegetarian          sweet  dessert   Madhya Pradesh     Central
# 254  vegetarian          sweet  dessert              Goa        West
#
#                                               Overview
# 0    Maida flour, yogurt, oil, sugar,vegetarian,swe...
# 1    Gram flour, ghee, sugar,vegetarian,sweet,desse...
# 2    Carrots, milk, sugar, ghee, cashews, raisins,v...
# 3    Flour, ghee, kewra, milk, clarified butter, su...
# 4    Milk powder, plain flour, baking powder, ghee,...
# ..                                                 ...
# 250  Glutinous rice, black sesame seeds, gur,vegeta...
# 251  Coconut milk, egg yolks, clarified butter, all...
# 252  Cottage cheese, dry dates, dried rose petals, ...
# 253  Milk powder, dry fruits, arrowroot powder, all...
# 254  Brown rice, fennel seeds, grated coconut, blac...
#
# [255 rows x 8 columns]

# %%
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %%
tfidf = TfidfVectorizer(stop_words='english')
data['Overview'] = data['Overview'].fillna('')
#Construct the required TF-IDF matrix by applying the fit_transform method on the overview feature
overview_matrix = tfidf.fit_transform(data['Overview'])
#Output the shape of tfidf_matrix
overview_matrix.shape
# Out:
# (255, 375)

# %%
similarity_matrix = linear_kernel(overview_matrix,overview_matrix)
similarity_matrix
# Out:
# array([[1.        , 0.31675242, 0.15414596, ..., 0.05922991, 0.10070141,
#         0.10573149],
#        [0.31675242, 1.        , 0.2899237 , ..., 0.06641366, 0.11291506,
#         0.11855522],
#        [0.15414596, 0.2899237 , 1.        , ..., 0.0745427 , 0.10928821,
#         0.06246208],
#        ...,
#        [0.05922991, 0.06641366, 0.0745427 , ..., 1.        , 0.10598731,
#         0.04025529],
#        [0.10070141, 0.11291506, 0.10928821, ..., 0.10598731, 1.        ,
#         0.13990221],
#        [0.10573149, 0.11855522, 0.06246208, ..., 0.04025529, 0.13990221,
#         1.        ]])

# %%
mappingName = pd.Series(data.index,index = data['name'])
mappingName
# Out:
# name
# Balu shahi          0
# Boondi              1
# Gajar ka halwa      2
# Ghevar              3
# Gulab jamun         4
#                  ...
# Til Pitha         250
# Bebinca           251
# Shufta            252
# Mawa Bati         253
# Pinaca            254
# Length: 255, dtype: int64

# %%
def recommend_food_based_on_plot(data_input):
  if(data_input==''):
    return df
  data_index = mappingName[data_input]
  #get similarity values with other foods
  #similarity_score is the list of index and similarity matrix
  similarity_score = list(enumerate(similarity_matrix[data_index]))
  #sort in descending order the similarity score of food inputted with all the other foods
  similarity_score = sorted(similarity_score, key=lambda x: x[1], reverse=True)
  # Get the scores of the 15 most similar foods. Ignore the first food.
  similarity_score = similarity_score[1:15]
  #return food names using the mapping series
  data_indices = [i[0] for i in similarity_score]
  return (data.iloc[data_indices])

# %%
food = input('Enter the food: ')
flavor_profile = input('Enter the Flavor Profile: ')
diet = input('Enter the diet: ')
course = input('Enter the course: ')
res=recommend_food_based_on_plot(data_input=food)
if(diet!=''):
  res = res[res['diet'] == diet]
if(flavor_profile !=''):
  res = res[res['flavor_profile'] == flavor_profile]
if(course!=''):
  res = res[res['course'] == course]
res
# Out:
# Enter the food: Tandoori Chicken
# Enter the Flavor Profile:
# Enter the diet: vegetarian
# Enter the course:
#                              name  \
# 116                         Rongi
# 86                      Dal tadka
# 74                  Bhindi masala
# 108           Paneer tikka masala
# 114                   Pindi chana
# 87                       Dum aloo
# 115                  Rajma chaval
# 100  Makki di roti sarson da saag
# 11                          Lassi
# 70                     Aloo matar
# 183                   Gatta curry
#
#                                            ingredients        diet  \
# 116  Garam masala powder, tomato, kasuri methi, cin...  vegetarian
# 86   Pigeon peas, garam masala, ginger, red onion, ...  vegetarian
# 74   Ladies finger, garam masala, kasuri methi, tom...  vegetarian
# 108  Paneer, greek yogurt, tandoori masala, cream, ...  vegetarian
# 114   Fennel, tea bags, tomato, kasuri methi, cinnamon  vegetarian
# 87   Baby potatoes, garam masala, cashew nuts, kasu...  vegetarian
# 115  Red kidney beans, garam masala powder, ginger,...  vegetarian
# 100  Palak, makki atta, mustard green, garam masala...  vegetarian
# 11                           Yogurt, milk, nuts, sugar  vegetarian
# 70   Potato, peas, chillies, ginger, garam masala, ...  vegetarian
# 183  Yogurt, besan, sauce, garam masala powder, gra...  vegetarian
#
#     flavor_profile       course            state region  \
# 116          spicy  main course           Punjab  North
# 86           spicy  main course           Punjab  North
# 74           spicy  main course           Punjab  North
# 108          spicy  main course           Punjab  North
# 114          spicy  main course           Punjab  North
# 87           spicy  main course  Jammu & Kashmir  North
# 115          spicy  main course            India  North
# 100          spicy  main course           Punjab  North
# 11           sweet      dessert           Punjab  North
# 70           spicy  main course           Punjab  North
# 183          spicy  main course        Rajasthan   West
#
#                                               Overview
# 116  Garam masala powder, tomato, kasuri methi, cin...
# 86   Pigeon peas, garam masala, ginger, red onion, ...
# 74   Ladies finger, garam masala, kasuri methi, tom...
# 108  Paneer, greek yogurt, tandoori masala, cream, ...
# 114  Fennel, tea bags, tomato, kasuri methi, cinnam...
# 87   Baby potatoes, garam masala, cashew nuts, kasu...
# 115  Red kidney beans, garam masala powder, ginger,...
# 100  Palak, makki atta, mustard green, garam masala...
# 11   Yogurt, milk, nuts, sugar,vegetarian,sweet,des...
# 70   Potato, peas, chillies, ginger, garam masala, ...
# 183  Yogurt, besan, sauce, garam masala powder, gra...
